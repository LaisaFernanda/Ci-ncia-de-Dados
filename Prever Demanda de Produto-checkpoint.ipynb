# %%
import pandas as pd

# %% [markdown]
# ## Extração dos dados - Coleta Segundária

# %%
df = pd.read_csv('BaseProdutos.csv')

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# ## Limpeza dos Dados - Preparação dos Dados e Análise Exploratória

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df['Outlet_Size'].fillna('Small',inplace=True)

# %% [markdown]
# ## Identificando a distribuição dos dados

# %%
import seaborn as sns

# %%
sns.pairplot(df, kind='reg')

# %%
sns.distplot(df['Item_Outlet_Sales']);

# %%
sns.boxplot(data = df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot=True, center=0)
# Out:
# <AxesSubplot:>

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                7060 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int32
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   int32
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   int32
#  6   Outlet_Establishment_Year  8523 non-null   int64
#  7   Outlet_Size                8523 non-null   int32
#  8   Outlet_Location_Type       8523 non-null   int32
#  9   Outlet_Type                8523 non-null   int32
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int32(6), int64(1)
# memory usage: 532.8 KB

# %%
df['Item_Visibility'] = df['Item_Visibility'].replace(0,np.mean(df['Item_Visibility']))

df['Outlet_Establishment_Year'] = 2013 - df['Outlet_Establishment_Year']

# %%
df['Item_Weight'].fillna((df['Item_Weight'].mean()), inplace=True)

# %%
from sklearn import preprocessing
t = preprocessing.LabelEncoder()

# %%
#df = df.drop('Outlet_Size', axis = 1)

# %%
df['Item_Fat_Content'] = t.fit_transform(df['Item_Fat_Content'])
df['Item_Type'] = t.fit_transform(df['Item_Type'])
df['Outlet_Identifier'] = t.fit_transform(df['Outlet_Identifier'])
df['Outlet_Location_Type'] = t.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type'] = t.fit_transform(df['Outlet_Type'])
df['Outlet_Size'] = t.fit_transform(df['Outlet_Size'])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0           FDA15         9.30                 1         0.016047          4
# 1           DRC01         5.92                 2         0.019278         14
# 2           FDN15        17.50                 1         0.016760         10
# 3           FDX07        19.20                 2         0.066132          6
# 4           NCD19         8.93                 1         0.066132          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                         14            1
# 1   48.2692                  3                          4            1
# 2  141.6180                  9                         14            1
# 3  182.0950                  0                         15            2
# 4   53.8614                  1                         26            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# ...

# %%
df = df.drop('Item_Identifier', axis = 1)

# %%
df_comp = df

# %%
x = df.drop('Item_Outlet_Sales', axis = 1)

# %%
df.columns
# Out:
# Index(['Item_Weight', 'Item_Fat_Content', 'Item_Visibility', 'Item_Type',
#        'Item_MRP', 'Outlet_Identifier', 'Outlet_Establishment_Year',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales'],
#       dtype='object')

# %%
df_comp['Item_Weight']=df_comp['Item_Weight'].apply(np.log1p)
df_comp['Item_Visibility']=df_comp['Item_Visibility'].apply(np.log1p)
df_comp['Item_Type']=df_comp['Item_Type'].apply(np.log1p)
df_comp['Item_MRP']=df_comp['Item_MRP'].apply(np.log1p)
df_comp['Outlet_Identifier']=df_comp['Outlet_Identifier'].apply(np.log1p)
df_comp['Outlet_Establishment_Year']=df_comp['Outlet_Establishment_Year'].apply(np.log1p)
df_comp['Outlet_Size']=df_comp['Outlet_Size'].apply(np.log1p)
df_comp['Outlet_Location_Type']=df_comp['Outlet_Location_Type'].apply(np.log1p)
df_comp['Outlet_Type']=df_comp['Outlet_Type'].apply(np.log1p)
df_comp['Item_Outlet_Sales']=df_comp['Item_Outlet_Sales'].apply(np.log1p)

# %%
sns.distplot(df_comp['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# ## Treinando o Modelo - Modelagem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Weight                8523 non-null   float64
#  1   Item_Fat_Content           8523 non-null   int32
#  2   Item_Visibility            8523 non-null   float64
#  3   Item_Type                  8523 non-null   float64
#  4   Item_MRP                   8523 non-null   float64
#  5   Outlet_Identifier          8523 non-null   float64
#  6   Outlet_Establishment_Year  8523 non-null   float64
#  7   Outlet_Size                8523 non-null   float64
#  8   Outlet_Location_Type       8523 non-null   float64
#  9   Outlet_Type                8523 non-null   float64
#  10  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(10), int32(1)
# memory usage: 699.3 KB

# %%
X_reg = df.iloc[:, 10].values
y_reg = df.iloc[:, 4].values
correlacao = np.corrcoef(X_reg, y_reg)
correlacao
# Out:
# array([[1.        , 0.56757445],
#        [0.56757445, 1.        ]])

# %%
modelo.intercept_
# Out:
# 95.81301031230208

# %%
X_reg = X_reg.reshape(-1, 1) 
modelo = LinearRegression()
modelo.fit(X_reg, y_reg)
# Out:
# LinearRegression()

# %%
import statsmodels.api as sm

# %%
X_sm = sm.add_constant(X_reg)
results = sm.OLS(y_reg, X_sm).fit()
results.summary()
results.predict(X_sm)
# Out:
# array([173.17675655, 104.99736949, 139.25254697, ..., 120.52528006,
#        134.03980257, 111.67188877])

# %%
 results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     4049.
# Date:                Thu, 13 May 2021   Prob (F-statistic):               0.00
# Time:                        18:03:21   Log-Likelihood:                -45649.
# No. Observations:                8523   AIC:                         9.130e+04
# Df Residuals:                    8521   BIC:                         9.132e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         95.8130      0.901    106.292      0.000      94.046      97.580
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split( x, df.Item_Outlet_Sales, test_size=0.25)

# %%
import warnings
warnings.filterwarnings("ignore")
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from lightgbm import LGBMRegressor
from sklearn.neural_network import MLPRegressor

regressor_list = [ KNeighborsRegressor(),
                  LinearRegression(),
                  DecisionTreeRegressor(),
                  RandomForestRegressor(),
                  XGBRegressor(),
                  MLPRegressor(),
                  LGBMRegressor(),
                  ]

for reg in regressor_list:
  print('Treinado', reg.__class__.__name__)
  reg.fit(X_train, y_train)
  train_score = reg.score(X_train, y_train)
  val_score = cross_val_score(reg, X_train, y_train, cv=5)
  test_score = reg.score(X_test, y_test)
  print('Score do Treino', train_score)
  print('Score da Validação', val_score)
  print('Score do Teste', test_score)
  print('='*80)
# Out:
# Treinado KNeighborsRegressor
# Score do Treino 0.6614576800290466
# Score da Validação [0.47865575 0.49019913 0.49138618 0.4676917  0.3981541 ]
# Score do Teste 0.499431956156305
# ...
# Treinado LinearRegression
# Score do Treino 0.5048930688644865
# Score da Validação [0.52345041 0.50320038 0.49181356 0.50373293 0.49575102]
# Score do Teste 0.49827473936369804
# ...
# Treinado DecisionTreeRegressor
# Score do Treino 1.0
# Score da Validação [0.15516822 0.19105177 0.203798   0.08360394 0.09721979]
# Score do Teste 0.20027289540315207
# ...
# Treinado RandomForestRegressor
# Score do Treino 0.9369244341198105
# Score da Validação [0.57153575 0.56122395 0.54169546 0.5326073  0.51800647]
# Score do Teste 0.5678038437814911
# ...
# Treinado XGBRegressor
# Score do Treino 0.859937542045658
# Score da Validação [0.53906902 0.52635539 0.49750663 0.5106535  0.50318562]
# Score do Teste 0.5457409033213262
# ...
# Treinado MLPRegressor
# Score do Treino 0.5384150279137332
# ...
